# %%
# !pip install requests beautifulsoup4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: requests in c:\users\naman\appdata\roaming\python\python312\site-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\naman\appdata\roaming\python\python312\site-packages (4.12.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\naman\appdata\roaming\python\python312\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\naman\appdata\roaming\python\python312\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\naman\appdata\roaming\python\python312\site-packages (from requests) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\naman\appdata\roaming\python\python312\site-packages (from requests) (2024.6.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\naman\appdata\roaming\python\python312\site-packages (from beautifulsoup4) (2.5)

# %%
import os
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

# URL of the page containing the links
url = 'https://ftp.ncbi.nlm.nih.gov/pubmed/baseline/'  # Replace with the actual URL

# Destination folder to save the downloaded files
destination_folder = 'Downloads/project work'  # For Google Colab, use /content as the base directory

# Create the folder if it doesn't exist
if not os.path.exists(destination_folder):
    os.makedirs(destination_folder)

# Send a GET request to the URL
response = requests.get(url)
response.raise_for_status()  # Raise an error for bad status codes

# Parse the HTML content of the page
soup = BeautifulSoup(response.content, 'html.parser')

# Find all <a> tags
links = soup.find_all('a')

# Download each XML link
for link in links:
    href = link.get('href')
    if href and (href.endswith('.xml') or 'xml' in href):
        full_url = urljoin(url, href)  # Handle relative URLs
        file_name = os.path.join(destination_folder, os.path.basename(full_url))
        print(f'Downloading {full_url} to {file_name}')
        try:
            file_response = requests.get(full_url)
            file_response.raise_for_status()
            with open(file_name, 'wb') as file:
                file.write(file_response.content)
            print(f'Successfully downloaded {file_name}')
        except requests.exceptions.RequestException as e:
            print(f'Failed to download {full_url}: {e}')
# Out:
# Downloading https://ftp.ncbi.nlm.nih.gov/pubmed/baseline/pubmed24n0001.xml.gz to Downloads/project work\pubmed24n0001.xml.gz
# Successfully downloaded Downloads/project work\pubmed24n0001.xml.gz
# Downloading https://ftp.ncbi.nlm.nih.gov/pubmed/baseline/pubmed24n0001.xml.gz.md5 to Downloads/project work\pubmed24n0001.xml.gz.md5
# Successfully downloaded Downloads/project work\pubmed24n0001.xml.gz.md5
# Downloading https://ftp.ncbi.nlm.nih.gov/pubmed/baseline/pubmed24n0002.xml.gz to Downloads/project work\pubmed24n0002.xml.gz
# Successfully downloaded Downloads/project work\pubmed24n0002.xml.gz
# Downloading https://ftp.ncbi.nlm.nih.gov/pubmed/baseline/pubmed24n0002.xml.gz.md5 to Downloads/project work\pubmed24n0002.xml.gz.md5
# Successfully downloaded Downloads/project work\pubmed24n0002.xml.gz.md5
# Downloading https://ftp.ncbi.nlm.nih.gov/pubmed/baseline/pubmed24n0003.xml.gz to Downloads/project work\pubmed24n0003.xml.gz
# Successfully downloaded Downloads/project work\pubmed24n0003.xml.gz
# Downloading https://ftp.ncbi.nlm.nih.gov/pubmed/baseline/pubmed24n0003.xml.gz.md5 to Downloads/project work\pubmed24n0003.xml.gz.md5
# Successfully downloaded Downloads/project work\pubmed24n0003.xml.gz.md5
# Downloading https://ftp.ncbi.nlm.nih.gov/pubmed/baseline/pubmed24n0004.xml.gz to Downloads/project work\pubmed24n0004.xml.gz
# Successfully downloaded Downloads/project work\pubmed24n0004.xml.gz
# Downloading https://ftp.ncbi.nlm.nih.gov/pubmed/baseline/pubmed24n0004.xml.gz.md5 to Downloads/project work\pubmed24n0004.xml.gz.md5
# Successfully downloaded Downloads/project work\pubmed24n0004.xml.gz.md5
# Downloading https://ftp.ncbi.nlm.nih.gov/pubmed/baseline/pubmed24n0005.xml.gz to Downloads/project work\pubmed24n0005.xml.gz
# Successfully downloaded Downloads/project work\pubmed24n0005.xml.gz
# Downloading https://ftp.ncbi.nlm.nih.gov/pubmed/baseline/pubmed24n0005.xml.gz.md5 to Downloads/project work\pubmed24n0005.xml.gz.md5
# Successfully downloaded Downloads/project work\pubmed24n0005.xml.gz.md5
# Downloading https://ftp.ncbi.nlm.nih.gov/pubmed/baseline/pubmed24n0006.xml.gz to Downloads/project work\pubmed24n0006.xml.gz
# Successfully downloaded Downloads/project work\pubmed24n0006.xml.gz
# Downloading https://ftp.ncbi.nlm.nih.gov/pubmed/baseline/pubmed24n0006.xml.gz.md5 to Downloads/project work\pubmed24n0006.xml.gz.md5

# %%
# !pip install xmltodict
# Out:
# Collecting xmltodict
#   Downloading xmltodict-0.13.0-py2.py3-none-any.whl (10.0 kB)
# Installing collected packages: xmltodict
# Successfully installed xmltodict-0.13.0

# %% [markdown]
# only to extract abstract from a single zip to json converted file

# %%
import gzip
import xmltodict
import json

# Path to the .xml.gz file
gz_file_path = '/content/downloads/pubmed24n0012.xml.gz'  # Update this with the path to your .xml.gz file

# Function to extract abstract from JSON data
def extract_abstract(json_data):
    if isinstance(json_data, dict):
        for key, value in json_data.items():
            if key.lower() == 'abstract':
                if isinstance(value, dict) and 'AbstractText' in value:
                    return value['AbstractText']
                elif isinstance(value, list):
                    for item in value:
                        if isinstance(item, dict) and 'AbstractText' in item:
                            return item['AbstractText']
            else:
                result = extract_abstract(value)
                if result:
                    return result
    elif isinstance(json_data, list):
        for item in json_data:
            result = extract_abstract(item)
            if result:
                return result
    return None

# Read the .xml.gz file, convert to JSON, and extract abstract
try:
    with gzip.open(gz_file_path, 'rt', encoding='utf-8') as xml_file:
        xml_content = xml_file.read()
        xml_dict = xmltodict.parse(xml_content)
        json_content = json.dumps(xml_dict, indent=4)

        # Print the JSON content (optional)
        # print(json_content)

        # Extract abstract from JSON
        abstract = extract_abstract(xml_dict)
        if abstract:
            print(f'Abstract found in {gz_file_path}:')
            print(abstract)
        else:
            print(f'No abstract found in {gz_file_path}')

except Exception as e:
    print(f'Failed to process {gz_file_path}: {e}')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-f8d4fa86ab9e> in <cell line: 2>()
#       1 import gzip
# ----> 2 import xmltodict
#       3 import json
#       4
#       5 # Path to the .xml.gz file
#
# ModuleNotFoundError: No module named 'xmltodict'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# code to extract abstract from all the zip files but only extract one abstract the first one not the all

# %%
import os
import gzip
import xmltodict

# Source directory containing .xml.gz files
source_dir = '/content/downloads'  # Update this with your source directory

# Destination directory to save extracted abstracts
destination_abstracts_dir = '/content/drive/MyDrive/abstract_text'  # Update this with your abstracts destination directory

# Create the destination directory if it doesn't exist
if not os.path.exists(destination_abstracts_dir):
    os.makedirs(destination_abstracts_dir)

# Function to extract abstract from JSON data
def extract_abstract(json_data):
    if isinstance(json_data, dict):
        for key, value in json_data.items():
            if key.lower() == 'abstract':
                if isinstance(value, dict) and 'AbstractText' in value:
                    return value['AbstractText']
                elif isinstance(value, list):
                    for item in value:
                        if isinstance(item, dict) and 'AbstractText' in item:
                            return item['AbstractText']
            else:
                result = extract_abstract(value)
                if result:
                    return result
    elif isinstance(json_data, list):
        for item in json_data:
            result = extract_abstract(item)
            if result:
                return result
    return None

# Function to process abstract text
def process_abstract_text(abstract_text):
    if isinstance(abstract_text, str):
        return abstract_text
    elif isinstance(abstract_text, list):
        processed_list = [process_abstract_text(item) for item in abstract_text]
        return ' '.join(filter(None, processed_list))
    elif isinstance(abstract_text, dict):
        return process_abstract_text(abstract_text.get('#text', ''))
    return ''

# Process each .xml.gz file in the source directory
for file_name in os.listdir(source_dir):
    if file_name.endswith('.xml.gz'):
        gz_file_path = os.path.join(source_dir, file_name)
        abstract_file_name = os.path.splitext(os.path.splitext(file_name)[0])[0] + '_abstract.txt'
        abstract_file_path = os.path.join(destination_abstracts_dir, abstract_file_name)

        try:
            with gzip.open(gz_file_path, 'rt', encoding='utf-8') as xml_file:
                xml_content = xml_file.read()
                xml_dict = xmltodict.parse(xml_content)

                # Extract abstract from JSON
                abstract = extract_abstract(xml_dict)
                if abstract:
                    abstract_text = process_abstract_text(abstract)
                    with open(abstract_file_path, 'w', encoding='utf-8') as abstract_file:
                        abstract_file.write(abstract_text)
                    print(f'Abstract extracted and saved for {gz_file_path}')
                else:
                    print(f'No abstract found in {gz_file_path}')

        except Exception as e:
            print(f'Failed to process {gz_file_path}: {e}')
# Out:
# Abstract extracted and saved for /content/downloads/pubmed24n0885.xml.gz
# Abstract extracted and saved for /content/downloads/pubmed24n0397.xml.gz
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-7fd20d6f558a> in <cell line: 49>()
#      56             with gzip.open(gz_file_path, 'rt', encoding='utf-8') as xml_file:
#      57                 xml_content = xml_file.read()
# ---> 58                 xml_dict = xmltodict.parse(xml_content)
#      59
#      60                 # Extract abstract from JSON
#
# /usr/local/lib/python3.10/dist-packages/xmltodict.py in parse(xml_input, encoding, expat, process_namespaces, namespace_separator, disable_entities, process_comments, **kwargs)
#     376         parser.Parse(b'',True)
#     377     else:
# --> 378         parser.Parse(xml_input, True)
#     379     return handler.item
#     380
#
# ../Modules/pyexpat.c in StartElement()
#
# /usr/local/lib/python3.10/dist-packages/xmltodict.py in startElement(self, full_name, attrs)
#     103     def startElement(self, full_name, attrs):
#     104         name = self._build_name(full_name)
# --> 105         attrs = self._attrs_to_dict(attrs)
#     106         if attrs and self.namespace_declarations:
#     107             attrs['xmlns'] = self.namespace_declarations
#
# /usr/local/lib/python3.10/dist-packages/xmltodict.py in _attrs_to_dict(self, attrs)
#      96         if isinstance(attrs, dict):
#      97             return attrs
# ---> 98         return self.dict_constructor(zip(attrs[0::2], attrs[1::2]))
#      99
#     100     def startNamespaceDecl(self, prefix, uri):
#
# KeyboardInterrupt:

# %% [markdown]
# # To extract all the abstract from a file

# %%
import os
import gzip
import xmltodict

# Source directory containing .xml.gz files
source_dir = '/content/downloads'  # Update this with your source directory

# Destination directory to save extracted abstracts
destination_abstracts_dir = '/content/abstracts'  # Update this with your abstracts destination directory

# Create the destination directory if it doesn't exist
if not os.path.exists(destination_abstracts_dir):
    os.makedirs(destination_abstracts_dir)

# Function to extract abstracts from JSON data
def extract_abstracts(json_data):
    abstracts = []
    if isinstance(json_data, dict):
        for key, value in json_data.items():
            if key.lower() == 'abstract':
                if isinstance(value, dict) and 'AbstractText' in value:
                    abstracts.append(value['AbstractText'])
                elif isinstance(value, list):
                    for item in value:
                        if isinstance(item, dict) and 'AbstractText' in item:
                            abstracts.append(item['AbstractText'])
            else:
                abstracts.extend(extract_abstracts(value))
    elif isinstance(json_data, list):
        for item in json_data:
            abstracts.extend(extract_abstracts(item))
    return abstracts

# Function to process abstract text
def process_abstract_text(abstract_text):
    if isinstance(abstract_text, str):
        return abstract_text
    elif isinstance(abstract_text, list):
        processed_list = [process_abstract_text(item) for item in abstract_text]
        return ' '.join(filter(None, processed_list))
    elif isinstance(abstract_text, dict):
        return process_abstract_text(abstract_text.get('#text', ''))
    return ''

# Process each .xml.gz file in the source directory
for file_name in os.listdir(source_dir):
    if file_name.endswith('.xml.gz'):
        gz_file_path = os.path.join(source_dir, file_name)
        base_name = os.path.splitext(os.path.splitext(file_name)[0])[0]

        try:
            with gzip.open(gz_file_path, 'rt', encoding='utf-8') as xml_file:
                xml_content = xml_file.read()
                xml_dict = xmltodict.parse(xml_content)

                # Extract abstracts from JSON
                abstracts = extract_abstracts(xml_dict)
                for idx, abstract in enumerate(abstracts):
                    if abstract:
                        abstract_text = process_abstract_text(abstract)
                        abstract_file_name = f"{base_name}_abstract_{idx + 1}.txt"
                        abstract_file_path = os.path.join(destination_abstracts_dir, abstract_file_name)
                        with open(abstract_file_path, 'w', encoding='utf-8') as abstract_file:
                            abstract_file.write(abstract_text)
                        print(f'Abstract {idx + 1} extracted and saved for {gz_file_path}')
                    else:
                        print(f'No abstract found in {gz_file_path}')

        except Exception as e:
            print(f'Failed to process {gz_file_path}: {e}')
# Out:
# Streaming output truncated to the last 5000 lines.
# Abstract 8416 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8417 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8418 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8419 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8420 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8421 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8422 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8423 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8424 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8425 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8426 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8427 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8428 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8429 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8430 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8431 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8432 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8433 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8434 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8435 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8436 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8437 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8438 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8439 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8440 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8441 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8442 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8443 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8444 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8445 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8446 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8447 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8448 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8449 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8450 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8451 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8452 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8453 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8454 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8455 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8456 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8457 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8458 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8459 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8460 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8461 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8462 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8463 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8464 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8465 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8466 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8467 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8468 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8469 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8470 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8471 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8472 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8473 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8474 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8475 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8476 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8477 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8478 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8479 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8480 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8481 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8482 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8483 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8484 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8485 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8486 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8487 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8488 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8489 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8490 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8491 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8492 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8493 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8494 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8495 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8496 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8497 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8498 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8499 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8500 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8501 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8502 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8503 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8504 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8505 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8506 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8507 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8508 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8509 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8510 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8511 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8512 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8513 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8514 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8515 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8516 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8517 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8518 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8519 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8520 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8521 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8522 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8523 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8524 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8525 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8526 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8527 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8528 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8529 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8530 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8531 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8532 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8533 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8534 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8535 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8536 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8537 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8538 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8539 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8540 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8541 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8542 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8543 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8544 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8545 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8546 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8547 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8548 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8549 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8550 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8551 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8552 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8553 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8554 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8555 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8556 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8557 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8558 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8559 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8560 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8561 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8562 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8563 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8564 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8565 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8566 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8567 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8568 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8569 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8570 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8571 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8572 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8573 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8574 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8575 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8576 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8577 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8578 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8579 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8580 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8581 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8582 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8583 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8584 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8585 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8586 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8587 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8588 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8589 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8590 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8591 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8592 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8593 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8594 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8595 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8596 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8597 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8598 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8599 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8600 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8601 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8602 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8603 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8604 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8605 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8606 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8607 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8608 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8609 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8610 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8611 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8612 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8613 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8614 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8615 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8616 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8617 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8618 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8619 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8620 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8621 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8622 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8623 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8624 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8625 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8626 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8627 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8628 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8629 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8630 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8631 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8632 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8633 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8634 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8635 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8636 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8637 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8638 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8639 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8640 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8641 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8642 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8643 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8644 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8645 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8646 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8647 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8648 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8649 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8650 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8651 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8652 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8653 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8654 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8655 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8656 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8657 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8658 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8659 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8660 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8661 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8662 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8663 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8664 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8665 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8666 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8667 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8668 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8669 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8670 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8671 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8672 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8673 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8674 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8675 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8676 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8677 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8678 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8679 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8680 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8681 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8682 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8683 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8684 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8685 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8686 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8687 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8688 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8689 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8690 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8691 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8692 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8693 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8694 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8695 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8696 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8697 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8698 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8699 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8700 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8701 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8702 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8703 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8704 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8705 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8706 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8707 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8708 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8709 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8710 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8711 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8712 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8713 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8714 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8715 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8716 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8717 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8718 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8719 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8720 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8721 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8722 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8723 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8724 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8725 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8726 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8727 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8728 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8729 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8730 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8731 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8732 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8733 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8734 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8735 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8736 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8737 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8738 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8739 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8740 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8741 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8742 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8743 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8744 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8745 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8746 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8747 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8748 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8749 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8750 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8751 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8752 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8753 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8754 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8755 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8756 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8757 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8758 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8759 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8760 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8761 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8762 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8763 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8764 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8765 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8766 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8767 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8768 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8769 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8770 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8771 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8772 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8773 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8774 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8775 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8776 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8777 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8778 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8779 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8780 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8781 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8782 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8783 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8784 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8785 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8786 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8787 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8788 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8789 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8790 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8791 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8792 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8793 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8794 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8795 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8796 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8797 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8798 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8799 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8800 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8801 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8802 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8803 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8804 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8805 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8806 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8807 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8808 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8809 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8810 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8811 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8812 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8813 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8814 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8815 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8816 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8817 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8818 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8819 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8820 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8821 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8822 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8823 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8824 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8825 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8826 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8827 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8828 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8829 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8830 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8831 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8832 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8833 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8834 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8835 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8836 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8837 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8838 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8839 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8840 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8841 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8842 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8843 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8844 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8845 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8846 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8847 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8848 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8849 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8850 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8851 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8852 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8853 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8854 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8855 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8856 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8857 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8858 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8859 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8860 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8861 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8862 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8863 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8864 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8865 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8866 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8867 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8868 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8869 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8870 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8871 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8872 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8873 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8874 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8875 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8876 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8877 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8878 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8879 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8880 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8881 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8882 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8883 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8884 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8885 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8886 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8887 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8888 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8889 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8890 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8891 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8892 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8893 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8894 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8895 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8896 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8897 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8898 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8899 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8900 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8901 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8902 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8903 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8904 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8905 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8906 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8907 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8908 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8909 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8910 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8911 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8912 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8913 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8914 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8915 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8916 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8917 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8918 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8919 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8920 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8921 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8922 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8923 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8924 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8925 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8926 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8927 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8928 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8929 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8930 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8931 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8932 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8933 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8934 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8935 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8936 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8937 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8938 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8939 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8940 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8941 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8942 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8943 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8944 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8945 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8946 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8947 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8948 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8949 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8950 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8951 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8952 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8953 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8954 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8955 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8956 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8957 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8958 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8959 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8960 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8961 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8962 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8963 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8964 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8965 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8966 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8967 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8968 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8969 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8970 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8971 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8972 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8973 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8974 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8975 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8976 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8977 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8978 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8979 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8980 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8981 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8982 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8983 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8984 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8985 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8986 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8987 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8988 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8989 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8990 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8991 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8992 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8993 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8994 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8995 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8996 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8997 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8998 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 8999 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 9000 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 9001 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 9002 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 9003 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 9004 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 9005 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 9006 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 9007 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 9008 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 9009 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 9010 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 9011 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 9012 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 9013 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 9014 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 9015 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 9016 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 9017 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 9018 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 9019 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 9020 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 9021 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 9022 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 9023 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 9024 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 9025 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 9026 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 9027 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 9028 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 9029 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# ...
# Abstract 13214 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13215 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13216 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13217 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13218 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13219 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13220 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13221 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13222 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13223 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13224 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13225 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13226 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13227 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13228 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13229 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13230 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13231 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13232 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13233 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13234 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13235 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13236 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13237 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13238 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13239 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13240 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13241 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13242 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13243 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13244 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13245 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13246 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13247 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13248 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13249 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13250 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13251 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13252 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13253 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13254 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13255 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13256 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13257 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13258 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13259 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13260 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13261 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13262 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13263 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13264 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13265 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13266 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13267 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13268 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13269 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13270 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13271 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13272 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13273 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13274 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13275 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13276 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13277 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13278 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13279 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13280 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13281 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13282 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13283 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13284 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13285 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13286 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13287 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13288 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13289 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13290 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13291 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13292 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13293 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13294 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13295 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13296 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13297 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13298 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13299 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13300 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13301 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13302 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13303 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13304 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13305 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13306 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13307 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13308 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13309 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13310 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13311 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13312 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13313 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13314 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13315 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13316 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13317 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13318 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13319 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13320 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13321 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13322 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13323 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13324 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13325 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13326 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13327 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13328 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13329 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13330 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13331 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13332 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13333 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13334 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13335 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13336 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13337 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13338 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13339 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13340 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13341 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13342 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13343 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13344 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13345 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13346 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13347 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13348 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13349 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13350 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13351 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13352 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13353 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13354 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13355 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13356 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13357 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13358 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13359 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13360 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13361 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13362 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13363 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13364 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13365 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13366 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13367 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13368 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13369 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13370 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13371 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13372 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13373 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13374 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13375 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13376 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13377 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13378 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13379 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13380 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13381 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13382 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13383 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13384 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13385 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13386 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13387 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13388 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13389 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13390 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13391 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13392 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13393 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13394 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13395 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13396 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13397 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13398 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13399 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13400 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13401 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13402 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13403 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13404 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13405 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13406 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13407 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13408 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13409 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13410 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13411 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13412 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13413 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13414 extracted and saved for /content/downloads/pubmed24n0002.xml.gz
# Abstract 13415 extracted and saved for /content/downloads/pubmed24n0002.xml.gz

# %% [markdown]
# To further extract the disseasse and symptoms

# %%
import spacy
import re

# Load spaCy model
nlp = spacy.load("en_core_web_sm")

# Define patterns for diseases and symptoms (adjust these as needed)
disease_patterns = [r"(disease|illness|condition)\s+([A-Za-z]+)",
                    r"([A-Za-z]+)\s+fever|([A-Za-z]+)\s+cancer|([A-Za-z]+)\s+syndrome"]
symptom_patterns = [r"([A-Za-z]+)\s+pain|headache|fever|nausea|cough|rash"]

def extract_entities(text):
  """
  This function extracts disease and symptom mentions from text using patterns and spaCy.

  Args:
      text: The text to process.

  Returns:
      A dictionary containing lists of disease and symptom mentions.
  """
  entities = {"diseases": [], "symptoms": []}
  for pattern in disease_patterns:
    matches = re.findall(pattern, text, re.IGNORECASE)
    for match in matches:
      entities["diseases"].append(match[0] if len(match) == 1 else match[1])

  for pattern in symptom_patterns:
    matches = re.findall(pattern, text, re.IGNORECASE)
    for match in matches:
      entities["symptoms"].append(match)

  # Optional: Use spaCy for named entity recognition (might improve results)
  doc = nlp(text)
  for ent in doc.ents:
    if ent.label_ in ("NOUN", "PROPN"):  # Match broader entity types
      entities["diseases"].append(ent.text)

  return entities

# Example usage
text = "I have a disease headache and a symptom fever, could it be the flu?"
entities = extract_entities(text)

print("Diseases:", entities["diseases"])
print("Symptoms:", entities["symptoms"])
# Out:
# Diseases: ['headache', '']
# Symptoms: ['', '']
